# %% [markdown]
# <a href="https://colab.research.google.com/github/long945/DataAnalyze/blob/main/HocsauLab01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
s = pd.Series([12,-4,7,9])
print (s)
# Out:
# 0    12
# 1    -4
# 2     7
# 3     9
# dtype: int64

# %%
s.values
# Out:
# array([12, -4,  7,  9])

# %%
import pandas as pd
s=pd.Series([12,-4,7,9], index=['a','b','c','d'])
print(s)
# Out:
# a    12
# b    -4
# c     7
# d     9
# dtype: int64

# %%
s.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
data ={'color' : ['blue', 'green', 'yellow', 'red', 'white'],
	'object': ['ball', 'pen', 'pencil', 'paper', 'mug'],
	'price': [1.2, 1.0, 0.6,0.9,1.7]}
frame = pd.DataFrame(data)
frame
# Out:
#     color  object  price
# 0    blue    ball    1.2
# 1   green     pen    1.0
# 2  yellow  pencil    0.6
# 3     red   paper    0.9
# 4   white     mug    1.7

# %%
frame2 = pd.DataFrame (data, columns = ['object', 'price'])
frame2
# Out:
#    object  price
# 0    ball    1.2
# 1     pen    1.0
# 2  pencil    0.6
# 3   paper    0.9
# 4     mug    1.7

# %%
frame2['type'] ='normal'
frame2
# Out:
#    object  price    type
# 0    ball    1.2  normal
# 1     pen    1.0  normal
# 2  pencil    0.6  normal
# 3   paper    0.9  normal
# 4     mug    1.7  normal

# %%
for i in range(len(frame2)):
  if frame2['price'][i] > 1.0:
    frame2.loc[i, 'type'] = 'good'
frame2
# Out:
#    object  price    type
# 0    ball    1.2    good
# 1     pen    1.0  normal
# 2  pencil    0.6  normal
# 3   paper    0.9  normal
# 4     mug    1.7    good

# %%
import pandas as pd
dulieuxettuyen = pd.read_csv("https://raw.githubusercontent.com/huynhhoc/DataAnalystDeepLearning/main/Data/dulieuxettuyendaihoc.csv")
print (dulieuxettuyen.head(10))
# Out:
#    STT   T1   L1   H1   S1   V1   X1  ...  GT  DT   KV   DH1   DH2   DH3  KT
# 0    1  7.2  7.3  6.3  7.3  7.0  7.9  ...   F NaN  2NT  3.25  3.25  4.50  A1
# 1    2  5.4  3.9  3.9  4.0  5.4  5.4  ...   M NaN    1  6.00  4.00  3.50   C
# 2    3  5.6  6.8  7.2  7.5  4.3  7.4  ...   M NaN    1  5.00  6.75  4.00   C
# 3    4  6.6  6.4  5.3  6.9  5.4  7.3  ...   M NaN    1  4.25  4.25  5.25  D1
# 4    5  6.0  5.0  6.0  7.3  6.5  7.7  ...   M NaN  2NT  4.25  4.50  5.00   A
# 5    6  9.3  7.6  7.9  8.6  7.0  7.3  ...   M NaN    1  1.50  4.00  6.00  D1
# 6    7  2.8  3.9  5.5  6.9  5.0  7.3  ...   F NaN    2  6.50  6.75  5.25   C
# 7    8  8.3  6.0  7.6  5.1  7.5  4.7  ...   F NaN    2  3.75  4.50  4.25  D1
# 8    9  6.5  6.3  7.6  6.0  5.5  7.1  ...   F NaN    1  3.50  3.50  6.75  D1
# 9   10  7.3  5.9  4.7  7.1  6.7  7.9  ...   F NaN    1  4.00  4.75  5.50  D1
#
# [10 rows x 56 columns]

# %%
import pandas as pd
heartDisease = pd.read_csv("https://raw.githubusercontent.com/huynhhoc/DataAnalystDeepLearning/main/Data/dulieuxettuyendaihoc.csv", header = None)
print (heartDisease)
# Out:
#       0    1    2    3    4    5    6   ...  49   50   51    52    53    54  55
# 0    STT   T1   L1   H1   S1   V1   X1  ...  GT   DT   KV   DH1   DH2   DH3  KT
# 1      1  7.2  7.3  6.3  7.3    7  7.9  ...   F  NaN  2NT  3.25  3.25   4.5  A1
# 2      2  5.4  3.9  3.9    4  5.4  5.4  ...   M  NaN    1     6     4   3.5   C
# 3      3  5.6  6.8  7.2  7.5  4.3  7.4  ...   M  NaN    1     5  6.75     4   C
# 4      4  6.6  6.4  5.3  6.9  5.4  7.3  ...   M  NaN    1  4.25  4.25  5.25  D1
# ..   ...  ...  ...  ...  ...  ...  ...  ...  ..  ...  ...   ...   ...   ...  ..
# 96    96  8.6  6.9  7.4  8.8  7.6  5.8  ...   F  NaN    1  5.25   1.5  6.25   C
# 97    97  3.7  5.4    6  5.1  5.5  3.9  ...   F  NaN    1  5.25  3.75  4.75   C
# 98    98  8.8  5.5  7.4  7.7  6.2  7.3  ...   M  NaN  2NT     7     8     4   C
# 99    99  2.7  1.8  3.4  5.3  4.5  7.9  ...   M  NaN    1     5   3.5   5.5   C
# 100  100  4.1  5.2  4.9  5.3  5.5  5.4  ...   M  NaN  2NT  5.25   2.5  4.25   C
#
# [101 rows x 56 columns]

# %%
import pandas as pd
import numpy as np
frame = pd.DataFrame(np.arange(16).reshape(4,4),
		index =['white', 'black', 'red','blue'],
		columns =['up', 'down', 'right', 'left'])
frame.to_json('frame.json')
#Read json-formatted data
jsonFrame = pd.read_json('frame.json')
print(jsonFrame)
# Out:
#        up  down  right  left
# white   0     1      2     3
# black   4     5      6     7
# red     8     9     10    11
# blue   12    13     14    15

# %%
import pandas as pd
example11 = pd.read_table('https://raw.githubusercontent.com/huynhhoc/DataAnalystDeepLearning/main/Data/example11.txt', sep='\D+', header=None, engine='python')
print (example11)
# Out:
#    0    1    2
# 0  0  123  122
# 1  1  124  321
# 2  2  125  333

# %%
import pandas as pd
example12 = pd.read_table('https://raw.githubusercontent.com/huynhhoc/DataAnalystDeepLearning/main/Data/example12.txt', sep=',', skiprows=[0,1,3,6])
print (example12)
# Out:
#    white  red  blue  green animal
# 0      1    5     2      3    cat
# 1      2    7     8      5    dog
# 2      3    3     6      7  horse
# 3      2    2     8      3   duck
# 4      4    4     2      1  mouse

# %%
import pandas as pd
import numpy as np
frame = pd.DataFrame(np.arange(16).reshape(4,4),index = ['red', 'blue', 'yellow','white'],columns = ['ball', 'pen', 'pencil', 'paper'])
print(frame)
# Out:
#         ball  pen  pencil  paper
# red        0    1       2      3
# blue       4    5       6      7
# yellow     8    9      10     11
# white     12   13      14     15

# %%
newframe = pd.DataFrame(frame, columns=['paper','pen'])
print(newframe)
# Out:
#         paper  pen
# red         3    1
# blue        7    5
# yellow     11    9
# white      15   13

# %%
filteredFrame = frame[frame < 11]
print(filteredFrame)
# Out:
#         ball  pen  pencil  paper
# red      0.0  1.0     2.0    3.0
# blue     4.0  5.0     6.0    7.0
# yellow   8.0  9.0    10.0    NaN
# white    NaN  NaN     NaN    NaN

# %%
dropNaNAllFrame = filteredFrame.dropna(how='all')
print(dropNaNAllFrame)
# Out:
#         ball  pen  pencil  paper
# red      0.0  1.0     2.0    3.0
# blue     4.0  5.0     6.0    7.0
# yellow   8.0  9.0    10.0    NaN

# %%
filteredFrame.isnull().sum()
# Out:
# ball      1
# pen       1
# pencil    1
# paper     2
# dtype: int64

# %% [markdown]
# LAB1

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("dulieuxettuyendaihoc.csv", index_col = "STT")
df.head(10)
# Out:
#       T1   L1   H1   S1   V1   X1   D1  ...  GT  DT   KV   DH1   DH2   DH3  KT
# STT                                     ...
# 1    7.2  7.3  6.3  7.3  7.0  7.9  7.3  ...   F NaN  2NT  3.25  3.25  4.50  A1
# 2    5.4  3.9  3.9  4.0  5.4  5.4  5.3  ...   M NaN    1  6.00  4.00  3.50   C
# 3    5.6  6.8  7.2  7.5  4.3  7.4  5.8  ...   M NaN    1  5.00  6.75  4.00   C
# 4    6.6  6.4  5.3  6.9  5.4  7.3  6.4  ...   M NaN    1  4.25  4.25  5.25  D1
# 5    6.0  5.0  6.0  7.3  6.5  7.7  7.9  ...   M NaN  2NT  4.25  4.50  5.00   A
# 6    9.3  7.6  7.9  8.6  7.0  7.3  7.7  ...   M NaN    1  1.50  4.00  6.00  D1
# 7    2.8  3.9  5.5  6.9  5.0  7.3  4.6  ...   F NaN    2  6.50  6.75  5.25   C
# 8    8.3  6.0  7.6  5.1  7.5  4.7  5.8  ...   F NaN    2  3.75  4.50  4.25  D1
# 9    6.5  6.3  7.6  6.0  5.5  7.1  6.3  ...   F NaN    1  3.50  3.50  6.75  D1
# 10   7.3  5.9  4.7  7.1  6.7  7.9  6.7  ...   F NaN    1  4.00  4.75  5.50  D1
#
# [10 rows x 55 columns]

# %% [markdown]
# Câu 3 : Sử dụng Python để tải dữ liệu lên chương trình và in ra màn hình 10 dòng đầu tiên và 10 dòng cuối cùng

# %%
df.head(10)
# Out:
#       T1   L1   H1   S1   V1   X1   D1  ...  GT  DT   KV   DH1   DH2   DH3  KT
# STT                                     ...
# 1    7.2  7.3  6.3  7.3  7.0  7.9  7.3  ...   F NaN  2NT  3.25  3.25  4.50  A1
# 2    5.4  3.9  3.9  4.0  5.4  5.4  5.3  ...   M NaN    1  6.00  4.00  3.50   C
# 3    5.6  6.8  7.2  7.5  4.3  7.4  5.8  ...   M NaN    1  5.00  6.75  4.00   C
# 4    6.6  6.4  5.3  6.9  5.4  7.3  6.4  ...   M NaN    1  4.25  4.25  5.25  D1
# 5    6.0  5.0  6.0  7.3  6.5  7.7  7.9  ...   M NaN  2NT  4.25  4.50  5.00   A
# 6    9.3  7.6  7.9  8.6  7.0  7.3  7.7  ...   M NaN    1  1.50  4.00  6.00  D1
# 7    2.8  3.9  5.5  6.9  5.0  7.3  4.6  ...   F NaN    2  6.50  6.75  5.25   C
# 8    8.3  6.0  7.6  5.1  7.5  4.7  5.8  ...   F NaN    2  3.75  4.50  4.25  D1
# 9    6.5  6.3  7.6  6.0  5.5  7.1  6.3  ...   F NaN    1  3.50  3.50  6.75  D1
# 10   7.3  5.9  4.7  7.1  6.7  7.9  6.7  ...   F NaN    1  4.00  4.75  5.50  D1
#
# [10 rows x 55 columns]

# %% [markdown]
# Câu 4 :Thống kê dữ liệu thiếu cho cột dân tộc và hiệu chỉnh dữ liệu thiếu như sau: Mặc định thiếu thì điền giá trị **0**

# %%
df["DT"].fillna(0, inplace =True)
df
# Out:
#       T1   L1   H1   S1   V1   X1   D1  ...  GT   DT   KV   DH1   DH2   DH3  KT
# STT                                     ...
# 1    7.2  7.3  6.3  7.3  7.0  7.9  7.3  ...   F  0.0  2NT  3.25  3.25  4.50  A1
# 2    5.4  3.9  3.9  4.0  5.4  5.4  5.3  ...   M  0.0    1  6.00  4.00  3.50   C
# 3    5.6  6.8  7.2  7.5  4.3  7.4  5.8  ...   M  0.0    1  5.00  6.75  4.00   C
# 4    6.6  6.4  5.3  6.9  5.4  7.3  6.4  ...   M  0.0    1  4.25  4.25  5.25  D1
# 5    6.0  5.0  6.0  7.3  6.5  7.7  7.9  ...   M  0.0  2NT  4.25  4.50  5.00   A
# ..   ...  ...  ...  ...  ...  ...  ...  ...  ..  ...  ...   ...   ...   ...  ..
# 96   8.6  6.9  7.4  8.8  7.6  5.8  7.3  ...   F  0.0    1  5.25  1.50  6.25   C
# 97   3.7  5.4  6.0  5.1  5.5  3.9  6.1  ...   F  0.0    1  5.25  3.75  4.75   C
# 98   8.8  5.5  7.4  7.7  6.2  7.3  8.1  ...   M  0.0  2NT  7.00  8.00  4.00   C
# 99   2.7  1.8  3.4  5.3  4.5  7.9  4.9  ...   M  0.0    1  5.00  3.50  5.50   C
# 100  4.1  5.2  4.9  5.3  5.5  5.4  7.2  ...   M  0.0  2NT  5.25  2.50  4.25   C
#
# [100 rows x 55 columns]

# %% [markdown]
# 1 : Thống kê dữ liệu thiếu cho biến T1 và hiệu chỉnh dữ liệu, lưu ý việc thay thế dữ liệu thiếu sử dụng phương pháp **Mean**

# %%
df["T1"].fillna(df["T1"].mean(), inplace =True)
def fill(col):
    return df[col].fillna(df[col].mean(), inplace =True)
df.dtypes
# Out:
# T1     float64
# L1     float64
# H1     float64
# S1     float64
# V1     float64
# X1     float64
# D1     float64
# N1     float64
# T2     float64
# L2     float64
# H2     float64
# S2     float64
# V2     float64
# X2     float64
# D2     float64
# N2     float64
# T3     float64
# L3     float64
# H3     float64
# S3     float64
# V3     float64
# X3     float64
# D3     float64
# N3     float64
# T4     float64
# L4     float64
# H4     float64
# S4     float64
# V4     float64
# X4     float64
# D4     float64
# N4     float64
# T5     float64
# L5     float64
# H5     float64
# S5     float64
# V5     float64
# X5     float64
# D5     float64
# N5     float64
# T6     float64
# L6     float64
# H6     float64
# S6     float64
# V6     float64
# X6     float64
# D6     float64
# N6     float64
# GT      object
# DT     float64
# KV      object
# DH1    float64
# DH2    float64
# DH3    float64
# KT      object
# dtype: object

# %%
is_float64 = df.dtypes == float
df_column_list = df.columns[is_float64].tolist()
df_column_list
# Out:
# ['T1',
#  'L1',
#  'H1',
#  'S1',
#  'V1',
#  'X1',
#  'D1',
#  'N1',
#  'T2',
#  'L2',
#  'H2',
#  'S2',
#  'V2',
#  'X2',
#  'D2',
#  'N2',
#  'T3',
#  'L3',
#  'H3',
#  'S3',
#  'V3',
#  'X3',
#  'D3',
#  'N3',
#  'T4',
#  'L4',
#  'H4',
#  'S4',
#  'V4',
#  'X4',
#  'D4',
#  'N4',
#  'T5',
#  'L5',
#  'H5',
#  'S5',
#  'V5',
#  'X5',
#  'D5',
#  'N5',
#  'T6',
#  'L6',
#  'H6',
#  'S6',
#  'V6',
#  'X6',
#  'D6',
#  'N6',
#  'DT',
#  'DH1',
#  'DH2',
#  'DH3']

# %%
df.head()
# Out:
#       T1   L1   H1   S1   V1   X1   D1  ...  GT   DT   KV   DH1   DH2   DH3  KT
# STT                                     ...
# 1    7.2  7.3  6.3  7.3  7.0  7.9  7.3  ...   F  0.0  2NT  3.25  3.25  4.50  A1
# 2    5.4  3.9  3.9  4.0  5.4  5.4  5.3  ...   M  0.0    1  6.00  4.00  3.50   C
# 3    5.6  6.8  7.2  7.5  4.3  7.4  5.8  ...   M  0.0    1  5.00  6.75  4.00   C
# 4    6.6  6.4  5.3  6.9  5.4  7.3  6.4  ...   M  0.0    1  4.25  4.25  5.25  D1
# 5    6.0  5.0  6.0  7.3  6.5  7.7  7.9  ...   M  0.0  2NT  4.25  4.50  5.00   A
#
# [5 rows x 55 columns]

# %%
for col in df_column_list:
    df[col].fillna(df[col].mean(), inplace =True)
df.head()
# Out:
#       T1   L1   H1   S1   V1   X1   D1  ...  GT   DT   KV   DH1   DH2   DH3  KT
# STT                                     ...
# 1    7.2  7.3  6.3  7.3  7.0  7.9  7.3  ...   F  0.0  2NT  3.25  3.25  4.50  A1
# 2    5.4  3.9  3.9  4.0  5.4  5.4  5.3  ...   M  0.0    1  6.00  4.00  3.50   C
# 3    5.6  6.8  7.2  7.5  4.3  7.4  5.8  ...   M  0.0    1  5.00  6.75  4.00   C
# 4    6.6  6.4  5.3  6.9  5.4  7.3  6.4  ...   M  0.0    1  4.25  4.25  5.25  D1
# 5    6.0  5.0  6.0  7.3  6.5  7.7  7.9  ...   M  0.0  2NT  4.25  4.50  5.00   A
#
# [5 rows x 55 columns]

# %%
df.isnull().values.any()
# Out:
# False

# %%
for i in ["1","2","6"]:
    print("TBM"+i)
# Out:
# TBM1
# TBM2
# TBM6

# %%
for i in ["1","2","6"]:
    df["TBM"+i] = (df["T"+i]*2 + df["L"+i]+ df["H"+i]+ df["S"+i]+ + df["V"+i]*2 + df["X"+i]+ df["D"+i]+ df["N"+i])/10
df.rename(columns ={"TBM6":"TBM3"}, inplace =True)
df.head()
# Out:
#       T1   L1   H1   S1   V1   X1   D1  ...   DH1   DH2   DH3  KT  TBM1  TBM2  TBM3
# STT                                     ...
# 1    7.2  7.3  6.3  7.3  7.0  7.9  7.3  ...  3.25  3.25  4.50  A1  7.00  7.54  7.01
# 2    5.4  3.9  3.9  4.0  5.4  5.4  5.3  ...  6.00  4.00  3.50   C  4.69  5.47  5.07
# 3    5.6  6.8  7.2  7.5  4.3  7.4  5.8  ...  5.00  6.75  4.00   C  5.77  5.38  6.04
# 4    6.6  6.4  5.3  6.9  5.4  7.3  6.4  ...  4.25  4.25  5.25  D1  6.21  5.20  6.88
# 5    6.0  5.0  6.0  7.3  6.5  7.7  7.9  ...  4.25  4.50  5.00   A  6.50  6.36  6.99
#
# [5 rows x 58 columns]

# %%
for i in ["1","2","3"]:
    df["US_TBM"+i] = df["TBM"+i]/10 *4
df.head()
# Out:
#       T1   L1   H1   S1   V1   X1  ...  TBM1  TBM2  TBM3  US_TBM1  US_TBM2  US_TBM3
# STT                                ...
# 1    7.2  7.3  6.3  7.3  7.0  7.9  ...  7.00  7.54  7.01    2.800    3.016    2.804
# 2    5.4  3.9  3.9  4.0  5.4  5.4  ...  4.69  5.47  5.07    1.876    2.188    2.028
# 3    5.6  6.8  7.2  7.5  4.3  7.4  ...  5.77  5.38  6.04    2.308    2.152    2.416
# 4    6.6  6.4  5.3  6.9  5.4  7.3  ...  6.21  5.20  6.88    2.484    2.080    2.752
# 5    6.0  5.0  6.0  7.3  6.5  7.7  ...  6.50  6.36  6.99    2.600    2.544    2.796
#
# [5 rows x 61 columns]

# %%
for i in df["KT"].unique():
    str(i)
    df.loc[(i == "A1" or i == "A") & (((df["DH1"]*2 + df["DH2"] + df["DH3"])/4) >= 5), "KQXT"] = 1
    df.loc[(i == "A1" or i == "A") & (((df["DH1"]*2 + df["DH2"] + df["DH3"])/4) < 5), "KQXT"] = 0
    
    df.loc[(i == "B") & (((df["DH1"] + df["DH2"]*2 + df["DH3"])/4) >= 5), "KQXT"] = 1
    df.loc[(i == "B") & (((df["DH1"] + df["DH2"]*2 + df["DH3"])/4) < 5), "KQXT"] = 0
    
    df.loc[(i != "A1" or i != "A" or i == "B") & (((df["DH1"] + df["DH2"] + df["DH3"])/3) >= 5), "KQXT"] = 1
    df.loc[(i != "A1" or i != "A" or i == "B") & (((df["DH1"] + df["DH2"] + df["DH3"])/3) < 5), "KQXT"] = 0
df.head(100)
# Out:
#       T1   L1   H1   S1   V1   X1  ...  TBM2  TBM3  US_TBM1  US_TBM2  US_TBM3  KQXT
# STT                                ...
# 1    7.2  7.3  6.3  7.3  7.0  7.9  ...  7.54  7.01    2.800    3.016    2.804   0.0
# 2    5.4  3.9  3.9  4.0  5.4  5.4  ...  5.47  5.07    1.876    2.188    2.028   0.0
# 3    5.6  6.8  7.2  7.5  4.3  7.4  ...  5.38  6.04    2.308    2.152    2.416   1.0
# 4    6.6  6.4  5.3  6.9  5.4  7.3  ...  5.20  6.88    2.484    2.080    2.752   0.0
# 5    6.0  5.0  6.0  7.3  6.5  7.7  ...  6.36  6.99    2.600    2.544    2.796   0.0
# ..   ...  ...  ...  ...  ...  ...  ...   ...   ...      ...      ...      ...   ...
# 96   8.6  6.9  7.4  8.8  7.6  5.8  ...  7.42  6.83    2.972    2.968    2.732   0.0
# 97   3.7  5.4  6.0  5.1  5.5  3.9  ...  5.15  6.39    1.972    2.060    2.556   0.0
# 98   8.8  5.5  7.4  7.7  6.2  7.3  ...  7.84  7.67    2.820    3.136    3.068   1.0
# 99   2.7  1.8  3.4  5.3  4.5  7.9  ...  4.72  5.29    1.660    1.888    2.116   0.0
# 100  4.1  5.2  4.9  5.3  5.5  5.4  ...  5.72  5.85    2.104    2.288    2.340   0.0
#
# [100 rows x 62 columns]

# %%
print(df)
# Out:
#       T1   L1   H1   S1   V1   X1  ...  TBM2  TBM3  US_TBM1  US_TBM2  US_TBM3  KQXT
# STT                                ...
# 1    7.2  7.3  6.3  7.3  7.0  7.9  ...  7.54  7.01    2.800    3.016    2.804   0.0
# 2    5.4  3.9  3.9  4.0  5.4  5.4  ...  5.47  5.07    1.876    2.188    2.028   0.0
# 3    5.6  6.8  7.2  7.5  4.3  7.4  ...  5.38  6.04    2.308    2.152    2.416   1.0
# 4    6.6  6.4  5.3  6.9  5.4  7.3  ...  5.20  6.88    2.484    2.080    2.752   0.0
# 5    6.0  5.0  6.0  7.3  6.5  7.7  ...  6.36  6.99    2.600    2.544    2.796   0.0
# ..   ...  ...  ...  ...  ...  ...  ...   ...   ...      ...      ...      ...   ...
# 96   8.6  6.9  7.4  8.8  7.6  5.8  ...  7.42  6.83    2.972    2.968    2.732   0.0
# 97   3.7  5.4  6.0  5.1  5.5  3.9  ...  5.15  6.39    1.972    2.060    2.556   0.0
# 98   8.8  5.5  7.4  7.7  6.2  7.3  ...  7.84  7.67    2.820    3.136    3.068   1.0
# 99   2.7  1.8  3.4  5.3  4.5  7.9  ...  4.72  5.29    1.660    1.888    2.116   0.0
# 100  4.1  5.2  4.9  5.3  5.5  5.4  ...  5.72  5.85    2.104    2.288    2.340   0.0
#
# [100 rows x 62 columns]

# %%
from google.colab import drive
drive.mount('/drive')
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).

# %%
df.to_csv('/drive /My Drive / DataAnalyst/processed_dulieuxettuyendaihoc.csv')

# %%
for i in ['1','2','3']:
  df.loc[df['TBM'+i]<5,'XL'+i] = 'Y'
  df.loc[(df['TBM'+i]<=6.5) & (df['TBM'+i]>5),'XL'+i] = 'TB'
  df.loc[(df['TBM'+i] < 8) & (df['TBM'+i]>=6.5),'XL'+i] = 'K'
  df.loc[(df['TBM'+i] < 9) & (df['TBM'+i]>=8),'XL'+i] = 'G'
  df.loc[(df['TBM'+i] >=9) ,'XL'+i] = 'XS'
print(df)
# Out:
#       T1   L1   H1   S1   V1   X1  ...  US_TBM2  US_TBM3  KQXT  XL1  XL2  XL3
# STT                                ...
# 1    7.2  7.3  6.3  7.3  7.0  7.9  ...    3.016    2.804   0.0    K    K    K
# 2    5.4  3.9  3.9  4.0  5.4  5.4  ...    2.188    2.028   0.0    Y   TB   TB
# 3    5.6  6.8  7.2  7.5  4.3  7.4  ...    2.152    2.416   1.0   TB   TB   TB
# 4    6.6  6.4  5.3  6.9  5.4  7.3  ...    2.080    2.752   0.0   TB   TB    K
# 5    6.0  5.0  6.0  7.3  6.5  7.7  ...    2.544    2.796   0.0    K   TB    K
# ..   ...  ...  ...  ...  ...  ...  ...      ...      ...   ...  ...  ...  ...
# 96   8.6  6.9  7.4  8.8  7.6  5.8  ...    2.968    2.732   0.0    K    K    K
# 97   3.7  5.4  6.0  5.1  5.5  3.9  ...    2.060    2.556   0.0    Y   TB   TB
# 98   8.8  5.5  7.4  7.7  6.2  7.3  ...    3.136    3.068   1.0    K    K    K
# 99   2.7  1.8  3.4  5.3  4.5  7.9  ...    1.888    2.116   0.0    Y    Y   TB
# 100  4.1  5.2  4.9  5.3  5.5  5.4  ...    2.288    2.340   0.0   TB   TB   TB
#
# [100 rows x 65 columns]
